# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import PIL

# %matplotlib inline

# %%
from torchvision import transforms
from preprocessing import CustomDataset
from torch.utils.data import DataLoader


root_dir = "competition-data"
img_dirs = ['training-images', 'validation-images']
depth_dirs = ['training-depths', 'validation-depths']
ds = []
for img_dir, depth_dir in zip(img_dirs, depth_dirs):
    d = CustomDataset(img_dir=img_dir, depth_dir=depth_dir, root_dir=root_dir, transform=transforms.ToTensor(), target_transform=transforms.ToTensor())
